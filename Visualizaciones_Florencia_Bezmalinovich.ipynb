# %% [markdown]
# <a href="https://colab.research.google.com/github/FlorenciaBezmalinovich/traqueo_vuelos/blob/main/Visualizaciones_Florencia_Bezmalinovich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1° Entrega: Selecciones**
#
# Hola 😊! Para esta primer entrega seleccioné 3 datasets con distinto potencial 🧨 y mis planes son analizar 1 o 2 proyectos en simultaneo al proyecto final.
#
# *Me podrias aconsejar cuales serian los más idoneos para trabajar? Muchas gracias!! 🦾*

# %% [markdown]
# ## Librerías
# - Importando Pandas
#
# - Instalación de las credencias de la API de Kaggle para descargar los datasets

# %%
import pandas as pd

# %%
#Importar libreria desde GitHub
url="https://raw.githubusercontent.com/FlorenciaBezmalinovich/traqueo_vuelos/main/Traqueo_vuelos_argentinos_2020_2022%20-%20limpio.csv"
df_vuelo= pd.read_csv(url)
df_vuelo.head()
# Out:
#    Index   Fecha UTC        Hora UTC Clase de Vuelo (todos los vuelos)  \
# 0      1  01/01/2022  11:58:00 p. m.                           Regular
# 1      2  01/01/2022  11:56:00 p. m.                           Regular
# 2      3  01/01/2022  11:55:00 p. m.                           Regular
# 3      4  01/01/2022  11:50:00 p. m.                           Regular
# 4      5  01/01/2022  11:49:00 p. m.                           Regular
#
#   Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0           Doméstico         ATERRIZAJE        IGU              CBA
# 1           Doméstico         ATERRIZAJE        JUJ              AER
# 2           Doméstico         ATERRIZAJE        AER              DOZ
# 3           Doméstico         ATERRIZAJE        JUJ              AER
# 4           Doméstico         ATERRIZAJE        BAR              AER
#
#               Aerolinea Nombre  Pasajeros
# 0     AEROLINEAS ARGENTINAS SA         71
# ...

# %%
#Importar libreria desde Drive
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/MyDrive'
df_vuelo= pd.read_csv('Traqueo_vuelos_argentinos_2020_2022 - limpio.csv')
# Out:
# /content/gdrive/MyDrive

# %%
# !pip install Kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !gdown --id 1yI2x4qazF5vuMFw_aof-4laGe366TyrJ

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ##**Datasets**

# %% [markdown]
# ### **1° Dataset: Traqueo de vuelos argentinos✈️**
# ---
#
# ![Captura de pantalla 2023-03-16 194525.png](data:image/png;base64,...)
#
# Fuente: https://datos.gob.ar/dataset/transporte-aterrizajes-despegues-procesados-por-administracion-nacional-aviacion-civil-anac
#
# El transporte aéreo o transporte por avión es el servicio de trasladar de un lugar a otro, pasajeros o cargamento, mediante la utilización de aeronaves dentro de un espacio aéreo.
#
# Durante la pandemia de la COVID-19 el transporte aéreo fue uno de los más afectados.
# La COVID-19 es la enfermedad causada por el nuevo coronavirus conocido como SARS-CoV-2. La Organización Mundial de la Salud (OMS) la declaró una emergencia de salud pública de importancia internacional el 30 de enero de 2020 y la reconoció como una pandemia el 11 de marzo de 2020.
#
#
# Durante la pandemia, período en el cual no despegaron ni aterrizaron vuelos comerciales con normalidad en ningún aeropuerto del mundo los mismos solo se utilizaron para vuelos de repatriación o traslado de vacunas para inoculación.
#
# Argentina no fue la excepción y a su vez cuando finalizó la pandemia algunas líneas aéreas habían dejado de volar en el territorio nacional.
#
# Para este trabajo se extrajo información de los aterrizajes y despegues de los aeropuertos de Argentina de los años 2020 y 2022, procesados por la Administración Nacional de Aviación Civil (ANAC).
#
# La temática a analizar en este dataset es cuanto fue la variación de los vuelos argentinos durante el año de pandemia vs. el año sin pandemía y con la mayor parte de la población inoculada. Además podremos evaluar la distribución de los pasajeros por hora, mes y día y proyectar cuales serán los vuelos con más tripulantes en el futuro.
#
# Esté fue el dataset que elegí para hacer el proyecto final en el curso de data analytics de Coderhose. En esa oportunidad use la base de datos desde enero 2021 hasta junio 2022 porque eran los datos publicados en ese momento. Para hacer el proyecto final del curso de data science volví a consultar la página y encontré que el dataset del año 2020 estaba completo junto con el del 2022. A continuación dejo una ruta de mi proyecto final del curso de data analytics: https://drive.google.com/drive/folders/1oJUO65P8wSZKh7iNhfjYb4vyBqDF352_?usp=share_link

# %%
df_vuelo.head()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-49639cdf-58f8-47c5-b93a-269ceac33c03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49639cdf-58f8-47c5-b93a-269ceac33c03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df_vuelo = pd.read_csv(io.BytesIO(uploaded['Traqueo_vuelos_argentinos_2020_2022.csv']),sep=';')

# %%
df_vuelo.head()

# %%
df_vuelo.shape

# %%
df_vuelo.columns.tolist()

# %% [markdown]
# #### Descripción de variables de interés:
# Fecha UTC: Fecha en la cual aterriza o despega el vuelo.
#
# Hora UTC: Hora en la cual aterriza o despega el vuelo.
#
# Clase de Vuelo (todos los vuelos): Incluye la clase del vuelo.
#
# Clasificación Vuelo: Incluye la clasificación del vuelo.
#
# Tipo de Movimiento: Aclara si es aterrizaje o despegue.
#
# Aeropuerto: Detalle el aeropuerto desde donde
# pueden partir o arribar el vuelo.
#
# Origen / Destino: Detalle el aeropuerto desde donde
# pueden partir o arribar el vuelo.
#
# Aerolinea Nombre: Detalla las aerolíneas del vuelo.
#
# Aeronave: Detalla el tipo de aeronave de ese vuelo.
#
# Pasajeros: Detalla la cantidad de pasajeros de cada vuelo.
#
# Calidad dato: Detalla la calidad del dato cargado en la base de
# datos nacional.

# %% [markdown]
# ### **2° Dataset: Venta de licores en distribuidora🥃**
#
# ---
#
#
#
#
# Fuente: https://www.kaggle.com/datasets/residentmario/iowa-liquor-sales?select=Iowa_Liquor_Sales.csv
#
# ![20046437_286247271842722_2343449206104565243_n.png](data:image/png;base64,...)
#
# Este dataset muestra las ventas de una distribuidoras de licores de Iowa indicando la fecha de venta, la cantidad y el precio vendido, la sucursal vendedora y el proveedor el cual abastecio el stock. Cuenta con datos desde agosto de 2Jan12 hasta 30Oct17.
#
# La temática a analizar en este caso será qué proveedor es el que nos provee la mayor cantidad de mercaderia vendida a fin de mejorar el convenio comercial, cuales son los porcentajes de ventas de las distintas sucursales para desarrollar metas de venta a cumplir customizadas. Además podremos proyectar cuales serán los licores más vendidos en un futuro a fines de definir una política de stock eficiente y real.

# %%
# !kaggle datasets download -d residentmario/iowa-liquor-sales

# %%
# !unzip -o iowa-liquor-sales.zip

# %%
df_sale = pd.read_csv('Iowa_Liquor_Sales.csv')

# %%
df_sale.head()

# %%
df_sale.shape

# %%
df_sale.columns.tolist()

# %% [markdown]
# #### Descripción de variables de interés:
# invoice_and_item_number:	Factura concatenada y número de línea asociado con el pedido de licor. Esto proporciona un identificador único para los productos de licores individuales incluidos en el pedido de la tienda.
#
# date:	Fecha de pedido.
#
# store_number:	Número único asignado a la tienda que ordenó el licor.
#
# store_name:	Nombre de la tienda que ordenó el licor.
#
# address:	Dirección de la tienda que ordenó el licor.
#
# city:	Ciudad donde se encuentra la tienda que ordenó el licor
#
# zip_code:	Código postal donde se encuentra la tienda que ordenó el licor
#
# store_location:	Ubicación de la tienda que ordenó el licor. La dirección, la ciudad, el estado y el código postal están geocodificados para proporcionar coordenadas geográficas. La precisión de la codificación geográfica depende de qué tan bien se interprete la dirección y de la integridad de los datos de referencia utilizados.
#
# county_number:	Número del condado de Iowa para el condado donde se encuentra la tienda que ordenó el licor.
#
# county:	Condado donde se encuentra la tienda que ordenó el licor.
#
# category:	Código de categoría asociado con el licor pedido.
#
# category_name:	Categoría del licor pedido.
#
# vendor_number:	El número de vendedor de la empresa para la marca de licor ordenada.
#
# vendor_name:	El nombre del proveedor de la empresa para la marca de licor ordenada.
#
# item_number:	Número de artículo para el producto de licor individual pedido.
#
# item_description:	Descripción del producto de licor individual pedido.
#
# pack:	El número de botellas en una caja para el licor pedido.
#
# bottle_volume_ml:	Volumen de cada botella de licor pedida en mililitros.
#
# state_bottle_cost:	El monto que la División de Bebidas Alcohólicas pagó por cada botella de licor ordenada.
#
# state_bottle_retail:	El monto que pagó la tienda por cada botella de licor que ordenó.
#
# bottles_sold:	El número de botellas de licor ordenadas por la tienda.
#
# sale_dollars:	Costo total del pedido de licor (número de botellas multiplicado por la venta minorista estatal de botellas).

# %% [markdown]
# ### **3° Dataset: Tendencias mundiales en salud mental🧠**
#
# ---
#
# ![image.png](data:image/png;base64,...)
#
#
# Fuente: https://www.kaggle.com/datasets/thedevastator/uncover-global-trends-in-mental-health-disorder
#
# Este dataset contiene datos informativos de países de todo el mundo sobre la prevalencia de los trastornos de salud mental, incluidos la esquizofrenia, el trastorno bipolar, los trastornos alimentarios, los trastornos de ansiedad, los trastornos por consumo de drogas, la depresión y los trastornos por consumo de alcohol  desde 1990 hasta 2017.
#
# Al proporcionar estos datos en un formato fácil de visualizar, puede obtener una idea de cómo estos problemas están afectando las vidas; lo que permite una comprensión más profunda de estas condiciones y las implicaciones.
#
# La información que puede arrojar este dataset será valiosa para la toma de decisiones, como ser el subsidio para la investigación de estas enfermedades o la elaboración de políticas píblicas o planes de intervención preventiva.
#
# Para eso primero crearé una visualización de la prevalencia de los trastornos de salud mental y luego desarrollaré modelos predictivos para la salud mental.

# %%
# !kaggle datasets download -d thedevastator/uncover-global-trends-in-mental-health-disorder

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !unzip -o uncover-global-trends-in-mental-health-disorder.zip

# %%
dataframe_mental_original = pd.read_csv('Mental health Depression disorder Data.csv')

# %%
dataframe_mental_original.shape

# %%
dataframe_mental = dataframe_mental_original[dataframe_mental_original["index"] < 6870]

# %%
dataframe_mental.shape

# %%
dataframe_mental.head()

# %%
dataframe_mental.columns.tolist()

# %% [markdown]
# #### Descripción de variables de interés:
# Index: Idetificador único.
#
# Entidad: Identificador único para cada país o región incluidos en el conjunto de datos.
#
# Código: único asociado a una Entidad/País o región incluida en el conjunto de datos.
#
# Año: en que se recopilaron los datos sobre esa Entidad/País en particular.
#
# Esquizofrenia (%): Porcentaje de personas con esquizofrenia en ese país/región durante ese año.
#
# Trastorno bipolar (%): Porcentaje de personas con trastorno bipolar en ese país/región durante ese año.
#
# Trastornos alimentarios (%): Porcentaje de personas con trastornos alimentarios en ese país/región durante ese año.
#
# Trastornos de ansiedad (%): Porcentaje de personas con trastornos de ansiedad en ese país/región durante ese año.
#
# Trastornos por consumo de drogas (%): Porcentaje de personas con trastornos por consumo de drogas en ese país/región durante ese año.
#
# Depresión (%): Porcentaje de personas con depresión en ese país/región durante ese año.
#
# Trastornos por consumo de alcohol (%): Porcentaje de personas con trastornos por consumo de alcohol en ese país/región durante ese año.

# %% [markdown]
# # **2° Entrega: Visualizaciones**
# ---
# Hola de nuevo 😊! Para la segunda entrega decidí elegir el dataset de traqueo de vuelos argentinos con el cual debo realizar 3 gráficos diferentes con Matplotlib y con Seaborn. Cada gráfico será interpretado con el fin de obtener insights relevantes que permitan dar respuesta a la pregunta problema.
#
# Fuente: https://datos.gob.ar/dataset/transporte-aterrizajes-despegues-procesados-por-administracion-nacional-aviacion-civil-anac
#
#
# *Espero tus comentarios. Muchas gracias!!* 🦾

# %% [markdown]
# ## Librerías
#
#
# *   Importación de matplotlib
# *   Importación de seaborn
# *   Selección del estilo Bayesian Methods for Hackers

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
mpl.style.use('bmh')

# %% [markdown]
# ##Visualizacion con Matplotlib y Seaborn
#
# Para comenzar consulté el tipo de datos que trae el dataset por defecto, luego definí las consultas que los 3 gráficos debían resolver:
#
# 1° ¿Cual es la hora pico de vuelos en el territorio argentino?
#
# 2° ¿Cual es el día de la semana donde hay más aeronaves sobrevolando el territorio nacional?
#
# 3° ¿Cuales son las 10 aerolineas con más vuelos en el país?

# %%
#Tipo de datos que trae el dataset por defecto
df_vuelo.dtypes
# Out:
# Index                                 int64
# Fecha UTC                            object
# Hora UTC                             object
# Clase de Vuelo (todos los vuelos)    object
# Clasificación Vuelo                  object
# Tipo de Movimiento                   object
# Aeropuerto                           object
# Origen / Destino                     object
# Aerolinea Nombre                     object
# Pasajeros                             int64
# dtype: object

# %%
#Gráfico 1: ¿Cual es la hora pico de vuelos en el territorio argentino? 
#1° Setear el campo hora que originalmente es un objeto como datetime: 
df_vuelo['Hora UTC'] = pd.to_datetime(df_vuelo['Hora UTC'])

# %%
df_vuelo.dtypes
# Out:
# Index                                         int64
# Fecha UTC                                    object
# Hora UTC                             datetime64[ns]
# Clase de Vuelo (todos los vuelos)            object
# Clasificación Vuelo                          object
# Tipo de Movimiento                           object
# Aeropuerto                                   object
# Origen / Destino                             object
# Aerolinea Nombre                             object
# Pasajeros                                     int64
# dtype: object

# %%
#2° Setear la columna Hora UTC como indice.
df_vuelo.set_index('Hora UTC', inplace=True)

# %%
df_vuelo.head()
# Out:
#                      Index   Fecha UTC Clase de Vuelo (todos los vuelos)  \
# Hora UTC
# 2023-04-04 23:58:00      1  01/01/2022                           Regular
# 2023-04-04 23:56:00      2  01/01/2022                           Regular
# 2023-04-04 23:55:00      3  01/01/2022                           Regular
# 2023-04-04 23:50:00      4  01/01/2022                           Regular
# 2023-04-04 23:49:00      5  01/01/2022                           Regular
#
#                     Clasificación Vuelo Tipo de Movimiento Aeropuerto  \
# Hora UTC
# 2023-04-04 23:58:00           Doméstico         ATERRIZAJE        IGU
# 2023-04-04 23:56:00           Doméstico         ATERRIZAJE        JUJ
# 2023-04-04 23:55:00           Doméstico         ATERRIZAJE        AER
# 2023-04-04 23:50:00           Doméstico         ATERRIZAJE        JUJ
# 2023-04-04 23:49:00           Doméstico         ATERRIZAJE        BAR
#
#                     Origen / Destino             Aerolinea Nombre  Pasajeros
# ...

# %%
#3° Crear una variable que cuento los vuelos por horas.
flights_per_hour = df_vuelo.resample('H').count()

# %%
import matplotlib.dates as mdates

# %%
#4° Gráfico 1 con Matplotlib
fig, ax = plt.subplots(figsize=(18, 4))
plt.plot(flights_per_hour.index, flights_per_hour,flights_per_hour['Index'])
plt.xlabel('Horas')
plt.ylabel('Cantidad de vuelos')
plt.title('Count of Flights per Hour')

hours = mdates.HourLocator(interval=1)  
formatter = mdates.DateFormatter('%H:%M') 

ax.xaxis.set_major_locator(hours)
ax.xaxis.set_major_formatter(formatter)

plt.show()

# %%
from dateutil import parser

# %%
#4° Gráfico 1 con Seaborn
#sns.lineplot(data=flights_per_hour, x=flights_per_hour.index, y='Index')
plt.xlabel('Hour')
plt.ylabel('Count of Flights')
plt.title('Count of Flights per Hour')

# Create plot using dateplot() function
sns.set_style('whitegrid')
ax = sns.lineplot(data=flights_per_hour, x=flights_per_hour.index, y='Index')
ax.set_xlabel('Time')

# Format x-axis labels to show only the hour component of dates
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = [parser.parse(label).strftime('%H:%M') for label in labels]
ax.set_xticklabels(labels)

# Show plot
sns.despine()
plt.show()
# Out:
# <ipython-input-62-eb137163ff9e>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
#5° Quitar a la hora como Index.
df_vuelo.reset_index('Hora UTC', inplace=True)

# %%
df_vuelo.head()
# Out:
#              Hora UTC  Index   Fecha UTC Clase de Vuelo (todos los vuelos)  \
# 0 2023-04-04 23:58:00      1  01/01/2022                           Regular
# 1 2023-04-04 23:56:00      2  01/01/2022                           Regular
# 2 2023-04-04 23:55:00      3  01/01/2022                           Regular
# 3 2023-04-04 23:50:00      4  01/01/2022                           Regular
# 4 2023-04-04 23:49:00      5  01/01/2022                           Regular
#
#   Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0           Doméstico         ATERRIZAJE        IGU              CBA
# 1           Doméstico         ATERRIZAJE        JUJ              AER
# 2           Doméstico         ATERRIZAJE        AER              DOZ
# 3           Doméstico         ATERRIZAJE        JUJ              AER
# 4           Doméstico         ATERRIZAJE        BAR              AER
#
#               Aerolinea Nombre  Pasajeros
# 0     AEROLINEAS ARGENTINAS SA         71
# ...

# %%
#Gráfico 2: ¿Cual es el día de la semana donde hay más aeronaves sobrevolando el territorio nacional?
#1° Formatear la fecha en datetime.
df_vuelo['Fecha UTC'] = pd.to_datetime(df_vuelo['Fecha UTC'])
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /usr/local/lib/python3.9/dist-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /usr/local/lib/python3.9/dist-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df_vuelo.head()
# Out:
#              Hora UTC  Index  Fecha UTC Clase de Vuelo (todos los vuelos)  \
# 0 2023-04-04 23:58:00      1 2022-01-01                           Regular
# 1 2023-04-04 23:56:00      2 2022-01-01                           Regular
# 2 2023-04-04 23:55:00      3 2022-01-01                           Regular
# 3 2023-04-04 23:50:00      4 2022-01-01                           Regular
# 4 2023-04-04 23:49:00      5 2022-01-01                           Regular
#
#   Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0           Doméstico         ATERRIZAJE        IGU              CBA
# 1           Doméstico         ATERRIZAJE        JUJ              AER
# 2           Doméstico         ATERRIZAJE        AER              DOZ
# 3           Doméstico         ATERRIZAJE        JUJ              AER
# 4           Doméstico         ATERRIZAJE        BAR              AER
#
#               Aerolinea Nombre  Pasajeros
# 0     AEROLINEAS ARGENTINAS SA         71
# ...

# %%
#2° Crear variable Día con el nombre del día de la semana correspondiente a esa fecha.
df_vuelo['Día'] = df_vuelo['Fecha UTC'].dt.day_name()

# %%
df_vuelo.head()
# Out:
#              Hora UTC  Index  Fecha UTC Clase de Vuelo (todos los vuelos)  \
# 0 2023-04-04 23:58:00      1 2022-01-01                           Regular
# 1 2023-04-04 23:56:00      2 2022-01-01                           Regular
# 2 2023-04-04 23:55:00      3 2022-01-01                           Regular
# 3 2023-04-04 23:50:00      4 2022-01-01                           Regular
# 4 2023-04-04 23:49:00      5 2022-01-01                           Regular
#
#   Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0           Doméstico         ATERRIZAJE        IGU              CBA
# 1           Doméstico         ATERRIZAJE        JUJ              AER
# 2           Doméstico         ATERRIZAJE        AER              DOZ
# 3           Doméstico         ATERRIZAJE        JUJ              AER
# 4           Doméstico         ATERRIZAJE        BAR              AER
#
#               Aerolinea Nombre  Pasajeros       Día
# 0     AEROLINEAS ARGENTINAS SA         71  Saturday
# ...

# %%
#3° Crear un dataframe que agrupe los vuelos por los días de la semana
flights_per_day = df_vuelo.groupby('Día')['Index'].count()

# %%
flights_per_day.head()
# Out:
# Día
# Friday      33697
# Monday      34131
# Saturday    34476
# Sunday      33212
# Thursday    33673
# Name: Index, dtype: int64

# %%
#4° Gráfico 2 con Matplotlib
plt.bar(flights_per_day.index, flights_per_day.values)
plt.xlabel('Day of the Week')
plt.ylabel('Count of Flights')
plt.title('Count of Flights per Day of the Week')
plt.show()

# %%
flights_per_day = df_vuelo.groupby('Día')['Index'].count().reset_index()

# %%
#4° Gráfico 2 con Seaborn
sns.barplot(data=flights_per_day, x='Día', y='Index')
plt.xlabel('Day of the Week')
plt.ylabel('Count of Flights')
plt.title('Count of Flights per Day of the Week')
plt.show()

# %%
#5° Validación de gráfico 2.
import statistics
mode_day = statistics.mode(df_vuelo['Día'])
print("La moda de los datos es:", mode_day)
# Out:
# La moda de los datos es: Saturday

# %%
# Grafico 3: ¿Cuales son las 10 aerolineas con más vuelos domésticos en el país (Matplotlib) y cuales con más vuelos internacionales (Seaborn)?
#1° Crear un dataframe que filtre los vuelos por su naturaleza de doméstico o internacional.
df_vuelos_domesticos = df_vuelo.loc[df_vuelo['Clasificación Vuelo'] =='Doméstico']
df_vuelos_internacionales = df_vuelo.loc[df_vuelo['Clasificación Vuelo'] =='Internacional']

# %%
#2° Crear el dataframe de vuelos domésticos y otro por vuelos internacionales filtrandolo por aerolinea.
domestics_flights_per_airline = df_vuelos_domesticos.groupby('Aerolinea Nombre')['Index'].count()
#international_flights_per_airline = df_vuelos_internacionales.groupby('Aerolinea Nombre')['Index'].count()

# %%
#3° Ordenar en cada dataframe las aerolineas por orden descendentes para que aparezcan las aerolineas con más vuelos al inicio.
domestics_flights_per_airline = domestics_flights_per_airline.sort_values(ascending=False)

# %%
#4° Filtrar las 10 primeras para mejor visualización.
domestics_flights_per_airline = (domestics_flights_per_airline[:5])

# %%
#5° Gráfico 3 con Matplotlib
plt.barh(domestics_flights_per_airline.index, domestics_flights_per_airline.values)
plt.xlabel('Count of Flights')
plt.ylabel('Airline')
plt.title('Number of Domestics Flights per Airline')
plt.show()

# %%
international_flights_per_airline = df_vuelos_internacionales.groupby('Aerolinea Nombre')['Index'].count().reset_index()

# %%
international_flights_per_airline = international_flights_per_airline.sort_values(by='Index', ascending=False)

# %%
international_flights_per_airline = (international_flights_per_airline[:5])

# %%
#4° Gráfico 3 con Seaborn
sns.barplot(data=international_flights_per_airline, x='Index', y='Aerolinea Nombre', color='blue')
plt.xlabel('Count of Flights')
plt.ylabel('Airline')
plt.title('Number of International Flights per Airline')

plt.show()
